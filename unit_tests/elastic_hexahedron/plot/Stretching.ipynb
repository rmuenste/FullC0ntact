# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("stretch_dt1e-2.txt")

# %%
plt.plot(data[:,0], data[:,1])

# %%
data2 = np.loadtxt("stretch_dt1e-3_10.txt")

# %%
plt.plot(data2[:,0], data2[:,1])

# %%
data3 = np.loadtxt("stretch.txt")

# %%
plt.plot(data3[:,0], data3[:,1])

# %%
data4 = np.loadtxt("stretch.txt")
plt.plot(data4[:,0], data4[:,1])

# %%
# %%html
# <img src="./ss-polypropylene.jpg"/>
# Out:
# <img src="./ss-polypropylene.jpg"/>
